# %% [markdown]
# # Lab 01 - Bài tập

# %% [markdown]
# ## PYTHON
#
# 1. Viết chương trình nhập vào số nguyên n (n>0). In ra các số nguyên tố từ 1..n

# %%
n = int(input("Nhap vao n: "))
for i in range(1,n):
    check = True
    if i < 2:
        check = False
    else:
        for j in range (2,int(i/2)+1):
            if i % j == 0:
                check = False
        if check:
            print(i)
# Out:
# 2
# 3
# 5
# 7

# %% [markdown]
# 2. Viết chương trình nhập vào số nguyên n có 3 chữ số. Tính tổng các chữ số của n

# %%
n=input("Nhap vao n:")
while len(n)!=3:
    break
sum=0
for i in n:
    sum+=int(i)
print(sum)
# Out:
# 6

# %% [markdown]
# 3. Viết chương trình nhập vào một dãy các số nguyên được cách nhau bởi khoảng trắng (VD: 32 8 4 6 9...) lưu vào python ở dạng mảng. Thực hiện
#
# - Xuất mảng
# - Tính tổng các phần tử của mảng
# - Tìm số lớn nhất
# - Tìm số bé nhất
# - Sắp xếp mảng theo thứ tự giảm dần
# - In ra các số chẵn trong mảng

# %%
arr=input("Nhap vao day mang, cach nhau bơi khoang trang: ")
numbers=[int(i) for i in arr.split()]
#Xuất mảng
print("Mảng lưu đươc:",numbers)
#Tính tổng các phần tử trong mang
sum=0
for i in numbers:
    sum+=i
print("tổng các phần tử trong mảnh",sum)
#Tìm số lớn nhất
max_numbers=max(numbers)
print("số lớn nhất:",max_numbers)
#Tìm số nhỏ nhất
min_numbers=min(numbers)
print("số nhỏ nhất:",min_numbers)
#Sắp xếp mảng theo thứ tự giảm dần (reverse=False: tăng, True giảm)
sapXep=sorted(numbers,reverse=True)
print("sắp xếp mảng giảm dần",sapXep)
#In ra các số chẵn trong mảng
soChan=[int(i) for i in numbers
if i%2==0]
print("Dãy số chẳn:",soChan)
# Out:
# Mảng lưu đươc: [2, 56, 4, 3, 6, 21, 5, 12, 30]
# tổng các phần tử trong mảnh 139
# số lớn nhất: 56
# số nhỏ nhất: 2
# sắp xếp mảng giảm dần [56, 30, 21, 12, 6, 5, 4, 3, 2]
# Dãy số chẳn: [2, 56, 4, 6, 12, 30]

# %% [markdown]
# 4. Viết chương trình yêu cầu người dùng nhập họ tên. Hiển thị tên người dùng sau khi đã chuẩn hóa. Biết rằng tên đã chuẩn hóa là:
# - Ký tự đầu viết hoa
# - Không có khoảng trắng thừa
# - Không có ký tự đặc biệt

# %%
str = input("Nhập họ và tên của bạn: ")
hoten = str.strip().title()
hoten=' '.join(str.split())
hoten = ''.join(e for e in ten_chuan_hoa if e.isalpha())
print("Tên của bạn:", hoten)
# Out:
# Tên của bạn: NgoVanToan

# %% [markdown]
# 5. Viết chương trình nhập vào một số nguyên dương (n>0). Cho biết n có phải là số đối xứng hay không? Biết số đối xứng là số viết xuôi hay viết ngược đều như nhau

# %%
def symmetrical_num(n): 
    flag =0
    if ( n[::-1] == n):
      flag = 1
    return flag
    #  return 1 if ( n[::-1] == n) else 0

n = input(">> nhap mot so tu nhien: ")
check = symmetrical_num(n);
 
if check == 1:
    print(n,"la so doi xung")
else:
    print(n,"khong phai la so doi xung")
# Out:
# 10 khong phai la so doi xung
