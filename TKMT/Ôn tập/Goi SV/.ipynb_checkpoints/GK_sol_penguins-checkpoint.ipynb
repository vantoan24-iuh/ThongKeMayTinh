# %%
MSV: 
Ho ten
So may: 30
Diem: 11 1-4-3-3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('penguins-data.csv')
df.info
df.head()
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           0  Adelie  Torgersen            39.1           18.7
# 1           1  Adelie  Torgersen            39.5           17.4
# 2           2  Adelie  Torgersen            40.3           18.0
# 3           4  Adelie  Torgersen            36.7           19.3
# 4           5  Adelie  Torgersen            39.3           20.6
#
#    flipper_length_mm  body_mass_g     sex
# 0              181.0       3750.0    MALE
# 1              186.0       3800.0  FEMALE
# 2              195.0       3250.0  FEMALE
# 3              193.0       3450.0  FEMALE
# 4              190.0       3650.0    MALE

# %%
df.describe()
# Out:
#        Unnamed: 0  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  333.000000      333.000000     333.000000         333.000000
# mean   172.303303       43.992793      17.164865         200.966967
# std     97.346548        5.468668       1.969235          14.015765
# min      0.000000       32.100000      13.100000         172.000000
# 25%     89.000000       39.500000      15.600000         190.000000
# 50%    172.000000       44.500000      17.300000         197.000000
# 75%    256.000000       48.600000      18.700000         213.000000
# max    343.000000       59.600000      21.500000         231.000000
#
#        body_mass_g
# count   333.000000
# mean   4207.057057
# std     805.215802
# min    2700.000000
# 25%    3550.000000
# 50%    4050.000000
# 75%    4775.000000
# max    6300.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             4  Adelie  Torgersen            36.7           19.3
# 4             5  Adelie  Torgersen            39.3           20.6
# ..          ...     ...        ...             ...            ...
# 328         338  Gentoo     Biscoe            47.2           13.7
# 329         340  Gentoo     Biscoe            46.8           14.3
# 330         341  Gentoo     Biscoe            50.4           15.7
# 331         342  Gentoo     Biscoe            45.2           14.8
# 332         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# 1                186.0       3800.0  FEMALE
# ...

# %%
# Câu 2a:

a = df['species'].value_counts()
print(a)
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64

# %%
a = df['island'].value_counts()
print(a)
# Out:
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: island, dtype: int64

# %%
# Câu 2b

df.groupby(['island','species']).size()
# Out:
# island     species
# Biscoe     Adelie        44
#            Gentoo       119
# Dream      Adelie        55
#            Chinstrap     68
# Torgersen  Adelie        47
# dtype: int64

# %%
# Câu 2b

# giá trị trung bình

df[['species','island','bill_length_mm','bill_depth_mm','flipper_length_mm']].groupby(['species','island']).mean()
# Out:
#                      bill_length_mm  bill_depth_mm  flipper_length_mm
# species   island
# Adelie    Biscoe          38.975000      18.370455         188.795455
#           Dream           38.520000      18.240000         189.927273
#           Torgersen       39.038298      18.451064         191.531915
# Chinstrap Dream           48.833824      18.420588         195.823529
# Gentoo    Biscoe          47.568067      14.996639         217.235294

# %%
df[['species','island','bill_length_mm','bill_depth_mm','flipper_length_mm']].groupby(['island','species']).median()
# Out:
#                      bill_length_mm  bill_depth_mm  flipper_length_mm
# island    species
# Biscoe    Adelie              38.70          18.45              189.5
#           Gentoo              47.40          15.00              216.0
# Dream     Adelie              38.80          18.40              190.0
#           Chinstrap           49.55          18.45              196.0
# Torgersen Adelie              39.00          18.40              191.0

# %%
# Câu 2b

# độ lệch chuẩn

df[['species','island','bill_length_mm','bill_depth_mm','flipper_length_mm']].groupby(['species','island']).std()
# Out:
#                      bill_length_mm  bill_depth_mm  flipper_length_mm
# species   island
# Adelie    Biscoe           2.480916       1.188820           6.729247
#           Dream            2.484276       1.140598           6.480325
#           Torgersen        3.028097       1.346472           6.220062
# Chinstrap Dream            3.339256       1.135395           7.131894
# Gentoo    Biscoe           3.106116       0.985998           6.585431

# %%
help(pd.DataFrame.groupby)
# Out:
# Help on function groupby in module pandas.core.frame:
#
# groupby(self, by=None, axis: 'Axis' = 0, level: 'Level | None' = None, as_index: 'bool' = True, sort: 'bool' = True, group_keys: 'bool' = True, squeeze: 'bool | lib.NoDefault' = <no_default>, observed: 'bool' = False, dropna: 'bool' = True) -> 'DataFrameGroupBy'
#     Group DataFrame using a mapper or by a Series of columns.
#
#     A groupby operation involves some combination of splitting the
#     object, applying a function, and combining the results. This can be
#     used to group large amounts of data and compute operations on these
#     groups.
#
#     Parameters
#     ----------
#     by : mapping, function, label, or list of labels
#         Used to determine the groups for the groupby.
#         If ``by`` is a function, it's called on each value of the object's
#         index. If a dict or Series is passed, the Series or dict VALUES
#         will be used to determine the groups (the Series' values are first
# ...

# %%
b = df.loc[(df['species']=='Gentoo')].groupby(['flipper_length_mm','body_mass_g'])
b.head()
# Out:
#      Unnamed: 0 species  island  bill_length_mm  bill_depth_mm  \
# 214         220  Gentoo  Biscoe            46.1           13.2
# 215         221  Gentoo  Biscoe            50.0           16.3
# 216         222  Gentoo  Biscoe            48.7           14.1
# 217         223  Gentoo  Biscoe            50.0           15.2
# 218         224  Gentoo  Biscoe            47.6           14.5
# ..          ...     ...     ...             ...            ...
# 328         338  Gentoo  Biscoe            47.2           13.7
# 329         340  Gentoo  Biscoe            46.8           14.3
# 330         341  Gentoo  Biscoe            50.4           15.7
# 331         342  Gentoo  Biscoe            45.2           14.8
# 332         343  Gentoo  Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 214              211.0       4500.0  FEMALE
# 215              230.0       5700.0    MALE
# 216              210.0       4450.0  FEMALE
# ...

# %%
# Câu 3

a = df.groupby(['species']).size().index.tolist()
b =  df.groupby(['species']).size().tolist()

plt.bar(a,b)
# Out:
# <BarContainer object of 3 artists>

# %%
a = df['species'].value_counts()
a.plot(kind='pie',autopct="%.2f%%")
# Out:
# <AxesSubplot:ylabel='species'>

# %%
# Câu 4
import seaborn as sns

# %%
# Hiển thị total_bill theo ngày, so sánh giữa thuộc tính hút thuốc hue='Gender',
sns.boxplot(data=df, y='body_mass_g', x='flipper_length_mm', width=0.5)
#plt.show()

# %%
# Câu 4
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# Câu 4
import seaborn as sns
sns.heatmap(b.corr())
# Out:
# <AxesSubplot:ylabel='flipper_length_mm-body_mass_g-None'>

# %%
sns.pairplot(df, hue = 'species')
